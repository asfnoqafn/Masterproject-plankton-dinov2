# %%
! python /home/olschulz/projects/Masterproject-plankton-dinov2/dinov2/data/dataset_creation/save_cpics_pngs_to_lmdb.py --dataset_path /home/olschulz/Documents/random_images --lmdb_dir_name /home/olschulz/Documents/whoi_lmdb
# Out:
# TOTAL #images 5000 FROM /home/olschulz/Documents/random_images
# ...
# 100%|███████████████████████████████████████| 5000/5000 [02:12<00:00, 37.77it/s]
# Finished importing from /home/olschulz/Documents/random_images and subdirectories, saved at: /home/olschulz/Documents/whoi_lmdb-TRAIN_imgs

# %%
! python /home/olschulz/projects/Masterproject-plankton-dinov2/dinov2/data/dataset_creation/save_imgs_to_lmdb.py --base_dir /home/olschulz/Documents/ --dataset_path /home/olschulz/projects/Masterproject-plankton-dinov2/random_images --lmdb_dir_name lmdbs --end_img_idx 500
# Out:
# PROCESSING DATASET stored in /home/olschulz/projects/Masterproject-plankton-dinov2/random_images...
# With labels: False, with metadata: False
# TOTAL #imgs 500
# ...
# 100%|████████████████████████████████████████| 500/500 [00:02<00:00, 196.21it/s]
# FINISHED DATASET SAVED AT: /home/olschulz/Documents/lmdbs/random_images
